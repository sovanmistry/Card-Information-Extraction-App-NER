# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from glob import glob
import string
import re
import spacy

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Clean Text Function

# %%
def cleanText(txt):
    
    whitespace = string.whitespace
    punctuation = "!#$%&\'()*+:;<=>?[\\]^`{|}~"
    tableWhitespace = str.maketrans('', '', whitespace)
    tablePunctuation = str.maketrans('', '', punctuation)
    
    text = str(txt)
    text = text.lower()
    removeWhiteSpace = text.translate(tableWhitespace)
    removePunctuation = removeWhiteSpace.translate(tablePunctuation)
    
    return str(removePunctuation)

# %% [markdown]
# ## Load NER Model

# %%
model_ner = spacy.load('./output/model-best')

# %% [markdown]
# ## Load Image

# %%
image = cv2.imread('./data/6.jpg')

cv2.imshow('Business Card', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Extract Data using pytesseract

# %%
tessData = pytesseract.image_to_data(image)
tessData
# Out:
# 'level\tpage_num\tblock_num\tpar_num\tline_num\tword_num\tleft\ttop\twidth\theight\tconf\ttext\n1\t1\t0\t0\t0\t0\t0\t0\t1065\t616\t-1\t\n2\t1\t1\t0\t0\t0\t3\t0\t1062\t5\t-1\t\n3\t1\t1\t1\t0\t0\t3\t0\t1062\t5\t-1\t\n4\t1\t1\t1\t1\t0\t3\t0\t1062\t5\t-1\t\n5\t1\t1\t1\t1\t1\t3\t0\t1062\t5\t95\t \n2\t1\t2\t0\t0\t0\t47\t44\t8\t119\t-1\t\n3\t1\t2\t1\t0\t0\t47\t44\t8\t119\t-1\t\n4\t1\t2\t1\t1\t0\t47\t44\t8\t119\t-1\t\n5\t1\t2\t1\t1\t1\t47\t44\t8\t119\t95\t \n2\t1\t3\t0\t0\t0\t46\t53\t979\t156\t-1\t\n3\t1\t3\t1\t0\t0\t722\t53\t303\t28\t-1\t\n4\t1\t3\t1\t1\t0\t722\t53\t303\t28\t-1\t\n5\t1\t3\t1\t1\t1\t722\t53\t64\t28\t90\tCell\n5\t1\t3\t1\t1\t2\t802\t60\t5\t20\t90\t:\n5\t1\t3\t1\t1\t3\t822\t53\t203\t28\t96\t8099948528\n3\t1\t3\t2\t0\t0\t55\t55\t970\t112\t-1\t\n4\t1\t3\t2\t1\t0\t55\t55\t970\t89\t-1\t\n5\t1\t3\t2\t1\t1\t55\t55\t85\t89\t30\tte)\n5\t1\t3\t2\t1\t2\t822\t71\t203\t65\t96\t8466045457\n4\t1\t3\t2\t2\t0\t593\t136\t432\t31\t-1\t\n5\t1\t3\t2\t2\t1\t593\t136\t93\t25\t89\temail\n5\t1\t3\t2\t2\t2\t669\t132\t21\t40\t88\t:\n5\t1\t3\t2\t2\t3\t709\t136\t316\t31\t88\tlictsrikant@gmail.com\n3\t1\t3\t3\t0\t0\t46\t151\t979\t58\t-1\t\n4\t1\t3\t3\t1\t0\t46\t151\t978\t58\t-1\t\n5\t1\t3\t3\t1\t1\t46\t170\t33\t14\t96\tLIFE\n5\t1\t3\t3\t1\t2\t85\t151\t91\t42\t94\tINSURANCE\n5\t1\t3\t3\t1\t3\t183\t170\t117\t14\t96\tCORPORATION\n5\t1\t3\t3\t1\t4\t306\t170\t20\t14\t96\tOF\n5\t1\t3\t3\t1\t5\t332\t170\t42\t14\t96\tINDIA\n5\t1\t3\t3\t1\t6\t668\t166\t119\t37\t92\tseosrika\n5\t1\t3\t3\t1\t7\t791\t165\t162\t44\t91\tntht@gmail\n5\t1\t3\t3\t1\t8\t958\t180\t66\t19\t69\t.com\n2\t1\t4\t0\t0\t0\t310\t227\t445\t32\t-1\t\n3\t1\t4\t1\t0\t0\t310\t227\t445\t32\t-1\t\n4\t1\t4\t1\t1\t0\t310\t227\t445\t32\t-1\t\n5\t1\t4\t1\t1\t1\t310\t228\t232\t30\t92\tTHATHINENI\n5\t1\t4\t1\t1\t2\t557\t227\t198\t32\t96\tSRIKANTH\n2\t1\t5\t0\t0\t0\t328\t271\t409\t70\t-1\t\n3\t1\t5\t1\t0\t0\t328\t271\t409\t70\t-1\t\n4\t1\t5\t1\t1\t0\t399\t271\t270\t25\t-1\t\n5\t1\t5\t1\t1\t1\t399\t271\t147\t25\t96\tInsurance\n5\t1\t5\t1\t1\t2\t555\t271\t114\t25\t96\tAdvisor\n4\t1\t5\t1\t2\t0\t328\t310\t409\t31\t-1\t\n5\t1\t5\t1\t2\t1\t328\t310\t89\t31\t96\tAgent\n5\t1\t5\t1\t2\t2\t428\t310\t80\t25\t96\tCode\n5\t1\t5\t1\t2\t3\t521\t310\t48\t25\t91\tNo.\n5\t1\t5\t1\t2\t4\t582\t310\t155\t25\t90\t0316164Y\n2\t1\t6\t0\t0\t0\t44\t395\t925\t203\t-1\t\n3\t1\t6\t1\t0\t0\t47\t395\t835\t32\t-1\t\n4\t1\t6\t1\t1\t0\t47\t395\t835\t32\t-1\t\n5\t1\t6\t1\t1\t1\t47\t396\t83\t30\t96\tLIFE\n5\t1\t6\t1\t1\t2\t145\t395\t236\t32\t96\tINSURANCE\n5\t1\t6\t1\t1\t3\t395\t395\t296\t32\t96\tCORPORATION\n5\t1\t6\t1\t1\t4\t706\t395\t53\t32\t94\tOF\n5\t1\t6\t1\t1\t5\t775\t396\t107\t30\t94\tINDIA\n3\t1\t6\t2\t0\t0\t45\t441\t658\t27\t-1\t\n4\t1\t6\t2\t1\t0\t45\t441\t658\t27\t-1\t\n5\t1\t6\t2\t1\t1\t45\t441\t36\t21\t96\tBr.\n5\t1\t6\t2\t1\t2\t93\t441\t45\t22\t96\tOff.\n5\t1\t6\t2\t1\t3\t149\t441\t42\t22\t96\tLIC\n5\t1\t6\t2\t1\t4\t201\t441\t79\t25\t93\tOffice,\n5\t1\t6\t2\t1\t5\t290\t441\t163\t27\t92\tTrimulgherry,\n5\t1\t6\t2\t1\t6\t465\t441\t101\t22\t92\tSec’bad\n5\t1\t6\t2\t1\t7\t576\t453\t8\t3\t91\t-\n5\t1\t6\t2\t1\t8\t594\t441\t46\t21\t96\t500\n5\t1\t6\t2\t1\t9\t650\t441\t53\t22\t95\t016.\n3\t1\t6\t3\t0\t0\t44\t474\t925\t124\t-1\t\n4\t1\t6\t3\t1\t0\t44\t474\t504\t27\t-1\t\n5\t1\t6\t3\t1\t1\t44\t474\t62\t21\t93\tAdd.\n5\t1\t6\t3\t1\t2\t118\t474\t144\t25\t92\tBorabanda,\n5\t1\t6\t3\t1\t3\t275\t474\t136\t27\t93\tHyderabad\n5\t1\t6\t3\t1\t4\t422\t486\t8\t3\t93\t-\n5\t1\t6\t3\t1\t5\t440\t474\t45\t21\t96\t500\n5\t1\t6\t3\t1\t6\t495\t474\t53\t21\t95\t018.\n4\t1\t6\t3\t2\t0\t46\t506\t871\t27\t-1\t\n5\t1\t6\t3\t2\t1\t46\t506\t430\t27\t86\tlictsrikant8099948528.blogspot.in,\n5\t1\t6\t3\t2\t2\t488\t506\t429\t27\t86\tinterviewsinhyderabad.blogspot.in\n4\t1\t6\t3\t3\t0\t44\t539\t925\t25\t-1\t\n5\t1\t6\t3\t3\t1\t44\t539\t472\t25\t87\tfacebook.com/lictsrikant8099948528,\n5\t1\t6\t3\t3\t2\t526\t539\t443\t22\t91\tfacebook.com/thathineni.srikanth.9\n4\t1\t6\t3\t4\t0\t46\t571\t482\t27\t-1\t\n5\t1\t6\t3\t4\t1\t46\t571\t106\t21\t96\tPromote\n5\t1\t6\t3\t4 ...

# %%
tessList = list(map(lambda x : x.split('\t'), tessData.split('\n')))
tessList
# Out:
# [['level',
#   'page_num',
#   'block_num',
#   'par_num',
#   'line_num',
#   'word_num',
#   'left',
#   'top',
#   'width',
#   'height',
#   'conf',
#   'text'],
#  ['1', '1', '0', '0', '0', '0', '0', '0', '1065', '616', '-1', ''],
#  ['2', '1', '1', '0', '0', '0', '3', '0', '1062', '5', '-1', ''],
#  ['3', '1', '1', '1', '0', '0', '3', '0', '1062', '5', '-1', ''],
#  ['4', '1', '1', '1', '1', '0', '3', '0', '1062', '5', '-1', ''],
#  ['5', '1', '1', '1', '1', '1', '3', '0', '1062', '5', '95', ' '],
#  ['2', '1', '2', '0', '0', '0', '47', '44', '8', '119', '-1', ''],
#  ['3', '1', '2', '1', '0', '0', '47', '44', '8', '119', '-1', ''],
#  ['4', '1', '2', '1', '1', '0', '47', '44', '8', '119', '-1', ''],
#  ['5', '1', '2', '1', '1', '1', '47', '44', '8', '119', '95', ' '],
#  ['2', '1', '3', '0', '0', '0', '46', '53', '979', '156', '-1', ''],
#  ['3', '1', '3', '1', '0', '0', '722', '53', '303', '28', '-1', ''],
#  ['4', '1', '3', '1', '1', '0', '722', '53', '303', '28', '-1', ''],
#  ['5', '1', '3', '1', '1', '1', '722', '53', '64', '28', '90', 'Cell'],
#  ['5', '1', '3', '1', '1', '2', '802', '60', '5', '20', '90', ':'],
#  ['5', '1', '3', '1', '1', '3', '822', '53', '203', '28', '96', '8099948528'],
#  ['3', '1', '3', '2', '0', '0', '55', '55', '970', '112', '-1', ''],
#  ['4', '1', '3', '2', '1', '0', '55', '55', '970', '89', '-1', ''],
#  ['5', '1', '3', '2', '1', '1', '55', '55', '85', '89', '30', 'te)'],
#  ['5', '1', '3', '2', '1', '2', '822', '71', '203', '65', '96', '8466045457'],
#  ['4', '1', '3', '2', '2', '0', '593', '136', '432', '31', '-1', ''],
#  ['5', '1', '3', '2', '2', '1', '593', '136', '93', '25', '89', 'email'],
#  ['5', '1', '3', '2', '2', '2', '669', '132', '21', '40', '88', ':'],
#  ['5',
#   '1',
#   '3',
#   '2',
#   '2',
#   '3',
#   '709',
#   '136',
#   '316',
#   '31',
#   '88',
#   'lictsrikant@gmail.com'],
#  ['3', '1', '3', '3', '0', '0', '46', '151', '979', '58', '-1', ''],
#  ['4', '1', '3', '3', '1', '0', '46', '151', '978', '58', '-1', ''],
#  ['5', '1', '3', '3', '1', '1', '46', '170', '33', '14', '96', 'LIFE'],
#  ['5', '1', '3', '3', '1', '2', '85', '151', '91', '42', '94', 'INSURANCE'],
#  ['5',
#   '1',
#   '3',
#   '3',
#   '1',
#   '3',
#   '183',
#   '170',
#   '117',
#   '14',
#   '96',
#   'CORPORATION'],
#  ['5', '1', '3', '3', '1', '4', '306', '170', '20', '14', '96', 'OF'],
#  ['5', '1', '3', '3', '1', '5', '332', '170', '42', '14', '96', 'INDIA'],
#  ['5', '1', '3', '3', '1', '6', '668', '166', '119', '37', '92', 'seosrika'],
#  ['5', '1', '3', '3', '1', '7', '791', '165', '162', '44', '91', 'ntht@gmail'],
#  ['5', '1', '3', '3', '1', '8', '958', '180', '66', '19', '69', '.com'],
#  ['2', '1', '4', '0', '0', '0', '310', '227', '445', '32', '-1', ''],
#  ['3', '1', '4', '1', '0', '0', '310', '227', '445', '32', '-1', ''],
#  ['4', '1', '4', '1', '1', '0', '310', '227', '445', '32', '-1', ''],
#  ['5', '1', '4', '1', '1', '1', '310', '228', '232', '30', '92', 'THATHINENI'],
#  ['5', '1', '4', '1', '1', '2', '557', '227', '198', '32', '96', 'SRIKANTH'],
#  ['2', '1', '5', '0', '0', '0', '328', '271', '409', '70', '-1', ''],
#  ['3', '1', '5', '1', '0', '0', '328', '271', '409', '70', '-1', ''],
#  ['4', '1', '5', '1', '1', '0', '399', '271', '270', '25', '-1', ''],
#  ['5', '1', '5', '1', '1', '1', '399', '271', '147', '25', '96', 'Insurance'],
#  ['5', '1', '5', '1', '1', '2', '555', '271', '114', '25', '96', 'Advisor'],
#  ['4', '1', '5', '1', '2', '0', '328', '310', '409', '31', '-1', ''],
#  ['5', '1', '5', '1', '2', '1', '328', '310', '89', '31', '96', 'Agent'],
#  ['5', '1', '5', '1', '2', '2', '428', '310', '80', '25', '96', 'Code'],
#  ['5', '1', '5', '1', '2', '3', '521', '310', '48', '25', '91', 'No.'],
#  ['5', '1', '5', '1', '2', '4', '582', '310', '155', '25', '90', '0316164Y'],
#  ['2', '1', '6', '0', '0', '0', '44', '395', '925', '203', '-1', ''],
#  ['3', '1', '6', '1', '0', '0', '47', '395', '835', '32', '-1', ''],
#  ['4', '1', '6', '1', '1', '0', '47', '395', '835', '32', '-1', ''],
#  ['5', '1', '6', '1', '1', '1', '47', '396', '83', '30', '96', 'LIFE'],
#  ['5', '1', '6', '1', '1', '2', '145', '395', '236', '32', '96', 'INSURANCE'],
#  ['5',
#   '1',
#   '6',
#   '1',
#   '1',
#   '3',
#   '395',
#   '395',
#   '296',
#   '32',
#   '96',
#   'CORPORATION'],
#  ['5', '1', '6', '1', '1', '4', '706', '395', '53', '32', '94', 'OF'],
#  ['5', '1', '6', '1', '1', '5', '775', '396', '107', '30', '94', 'INDIA'],
#  ['3', '1', '6', '2', '0', '0', '45', '441', '658', '27', '-1', ''],
#  ['4', '1', '6', '2', '1', '0', '45', '441', '658', '27', '-1', ''],
#  ['5', '1', '6', '2', '1', '1', '45', '441', '36', '21', '96', 'Br.'],
#  ['5', '1', '6', '2', '1', '2', '93', '441', '45', '22', '96', 'Off.'],
#  ['5', '1', '6', '2', '1', '3', '149', '441', '42', '22', '96', 'LIC'],
#  ['5', '1', '6', '2', '1', '4', '201', '441', '79', '25', '93', 'Office,'],
#  ['5',
#   '1',
#   '6',
#   '2',
#   '1',
#   '5',
#   '290',
#   '441',
#   '163',
#   '27',
#   '92',
#   'Trimulgherry,'],
#  ['5', '1', '6', '2', '1', '6', '465', '441', '101', '22', '92', 'Sec’bad'],
#  ['5', '1', '6', '2', '1', '7', '576', '453', '8', '3', '91', '-'],
#  ['5', '1', '6', '2', '1', '8', '594', '441', '46', '21', '96', '500'],
#  ['5', '1', '6', '2', '1', '9', '650', '441', '53', '22', '95', '016.'],
#  ['3', '1', '6', '3', '0', '0', '44', '474', '925', '124', '-1', ''],
#  ['4', '1', '6', '3', '1', '0', '44', '474', '504', '27', '-1', ''],
#  ['5', '1', '6', '3', '1', '1', '44', '474', '62', '21', '93', 'Add.'],
#  ['5', '1', '6', '3', '1', '2', '118', '474', '144', '25', '92', 'Borabanda,'],
#  ['5', '1', '6', '3', '1', '3', '275', '474', '136', '27', '93', 'Hyderabad'],
#  ['5', '1', '6', '3', '1', '4', '422', '486', '8', '3', '93', '-'],
#  ['5', '1', '6', '3', '1', '5', '440', '474', '45', '21', '96', '500'],
#  ['5', '1', '6', '3', '1', '6', '495', '474', '53', '21', '95', '018.'],
#  ['4', '1', '6', '3', '2', '0', '46', '506', '871', '27', '-1', ''],
#  ['5',
#   '1',
#   '6',
#   '3',
#   '2',
#   '1',
#   '46',
#   '506',
#   '430',
#   '27',
#   '86',
#   'lictsrikant8099948528.blogspot.in,'],
#  ['5',
#   '1',
#   '6',
#   '3',
#   '2',
#   '2',
#   '488',
#   '506',
#   '429',
#   '27',
#   '86',
#   'interviewsinhyderabad.blogspot.in'],
#  ['4', '1', '6', '3', '3', '0', '44', '539', '925', '25', '-1', ''],
#  ['5',
#   '1',
#   '6',
#   '3',
#   '3',
#   '1',
#   '44',
#   '539',
#   '472',
#   '25',
#   '87',
#   'facebook.com/lictsrikant8099948528,'],
#  ['5',
#   '1',
#   '6',
#   '3',
#   '3',
#   '2',
#   '526',
#   '539',
#   '443',
#   '22',
#   '91',
#   'facebook.com/thathineni.srikanth.9'],
#  ['4', '1', '6', '3', '4', '0', '46', '571', '482', '27', '-1', ''],
#  ['5', '1', '6', '3', '4', '1', '46', '571', '106', '21', '96', 'Promote'],
#  ['5', '1', '6', '3', '4', '2', '161', '576', '56', '22', '96', 'your'],
#  ['5', '1', '6', '3', '4', '3', '226', '571', '111', '21', '96', 'business'],
#  ['5', '1', '6', '3', '4', '4', '347', '571', '74', '21', '92', 'online'],
#  ['5', '1', '6', '3', '4', '5', '432', '571', '96', '27', '92', '(PYBO)'],
#  ['2', '1', '7', '0', '0', '0', '1061', '0', '4', '613', '-1', ''],
#  ['3', '1', '7', '1', '0', '0', '1061', '0', '4', '613', '-1', ''],
#  ['4', '1', '7', '1', '1', '0', '1061', '0', '4', '613', '-1', ''],
#  ['5', '1', '7', '1', '1', '1', '1061', '0', '4', '613', '95', ' '],
#  ['2', '1', '8', '0', '0', '0', '0', '607', '1065', '9', '-1', ''],
#  ['3', '1', '8', '1', '0', '0', '0', '607', '1065', '9', '-1', ''],
#  ['4', '1', '8', '1', '1', '0', '0', '607', '1065', '9', '-1', ''],
#  ['5', '1', '8', '1', '1', '1', '0', '607', '1065', '9', '95', ' '],
#  ['']]

# %%
df = pd.DataFrame(tessList[1:], columns=tessList[0])
df.head()
# Out:
#   level page_num block_num par_num line_num word_num left top width height  \
# 0     1        1         0       0        0        0    0   0  1065    616
# 1     2        1         1       0        0        0    3   0  1062      5
# 2     3        1         1       1        0        0    3   0  1062      5
# 3     4        1         1       1        1        0    3   0  1062      5
# 4     5        1         1       1        1        1    3   0  1062      5
#
#   conf text
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   95

# %%
# Removing Null values
df.dropna(inplace=True)

# %%
# Performing cleantext Function
df['text'] = df['text'].apply(cleanText)

# %% [markdown]
# ## Convert Data into Context

# %%
df_clean = df.query('text != "" ')
content = ' '.join([w for w in df_clean['text']])
print(content)
# Out:
# cell 8099948528 te 8466045457 email lictsrikant@gmail.com life insurance corporation of india seosrika ntht@gmail .com thathineni srikanth insurance advisor agent code no. 0316164y life insurance corporation of india br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018. lictsrikant8099948528.blogspot.in, interviewsinhyderabad.blogspot.in facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo

# %% [markdown]
# ## Get Predictions from NER Model

# %%
doc = model_ner(content)

# %%
from spacy import displacy

# %%
# Serve method to display the output

displacy.serve(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">cell
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8099948528
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  te
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8466045457
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  email
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seosrika
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ntht@gmail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     .com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thathineni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srikanth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#  agent code no. 0316164y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant8099948528.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-WEB</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     interviewsinhyderabad.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-WEB</span>
# </mark>
#  facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
# render method to display the output

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cell
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8099948528
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  te
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8466045457
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  email
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seosrika
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ntht@gmail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     .com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thathineni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srikanth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#  agent code no. 0316164y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant8099948528.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-WEB</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     interviewsinhyderabad.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-WEB</span>
# </mark>
#  facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo</div></span>

# %% [markdown]
# ## Tagging

# %%
docjson = doc.to_json()
docjson.keys()
# Out:
# dict_keys(['text', 'ents', 'tokens'])

# %%
docjson['text']
# Out:
# 'cell 8099948528 te 8466045457 email lictsrikant@gmail.com life insurance corporation of india seosrika ntht@gmail .com thathineni srikanth insurance advisor agent code no. 0316164y life insurance corporation of india br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018. lictsrikant8099948528.blogspot.in, interviewsinhyderabad.blogspot.in facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo'

# %%
docjson['ents'][0]
# Out:
# {'start': 5, 'end': 15, 'label': 'B-PHONE'}

# %%
docjson['tokens'][0]
# Out:
# {'id': 0, 'start': 0, 'end': 4}

# %%
# Create Data Frame with TOKENS

datafram_tokens = pd.DataFrame(docjson['tokens'])
datafram_tokens.head()
# Out:
#    id  start  end
# 0   0      0    4
# 1   1      5   15
# 2   2     16   18
# 3   3     19   29
# 4   4     30   35

# %%
doc_text = docjson['text']

# %%
# Add TEXT to our Data Frame

datafram_tokens['token'] = datafram_tokens[['start', 'end']].apply(lambda x:doc_text[x[0]: x[1]], axis =1)
datafram_tokens.head()
# Out:
#    id  start  end       token
# 0   0      0    4        cell
# 1   1      5   15  8099948528
# 2   2     16   18          te
# 3   3     19   29  8466045457
# 4   4     30   35       email

# %%
# Add ENTITIES(Labels) to our Data Frame

right_table = pd.DataFrame(docjson['ents'])[['start', 'label']]
right_table.head()
# Out:
#    start    label
# 0      5  B-PHONE
# 1     19  B-PHONE
# 2     36  B-EMAIL
# 3     58    B-ORG
# 4     63    I-ORG

# %%
datafram_tokens = pd.merge(datafram_tokens, right_table, how = 'left', on = 'start')
datafram_tokens.head()
# Out:
#    id  start  end       token    label
# 0   0      0    4        cell      NaN
# 1   1      5   15  8099948528  B-PHONE
# 2   2     16   18          te      NaN
# 3   3     19   29  8466045457  B-PHONE
# 4   4     30   35       email      NaN

# %%
# Fill NAN values with 'O'

datafram_tokens.fillna('O', inplace=True)
datafram_tokens.head()
# Out:
#    id  start  end       token    label
# 0   0      0    4        cell        O
# 1   1      5   15  8099948528  B-PHONE
# 2   2     16   18          te        O
# 3   3     19   29  8466045457  B-PHONE
# 4   4     30   35       email        O

# %% [markdown]
# ## Join Token DataFrame with Pytesseract Data

# %%
# Pytesseract Data

df_clean.head()
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 12     5        1         3       1        1        1  722   53    64     28
# 14     5        1         3       1        1        3  822   53   203     28
# 17     5        1         3       2        1        1   55   55    85     89
# 18     5        1         3       2        1        2  822   71   203     65
# 20     5        1         3       2        2        1  593  136    93     25
#
#    conf        text
# 12   90        cell
# 14   96  8099948528
# 17   30          te
# 18   96  8466045457
# 20   89       email

# %%
# Create end and start point from the df_clean Data Frame

df_clean['end'] = df_clean['text'].apply(lambda x : len(x)+1).cumsum()-1
df_clean.head()
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 12     5        1         3       1        1        1  722   53    64     28
# 14     5        1         3       1        1        3  822   53   203     28
# 17     5        1         3       2        1        1   55   55    85     89
# 18     5        1         3       2        1        2  822   71   203     65
# 20     5        1         3       2        2        1  593  136    93     25
#
#    conf        text  end
# 12   90        cell    4
# 14   96  8099948528   15
# 17   30          te   18
# 18   96  8466045457   29
# 20   89       email   35

# %%
df_clean['start'] = df_clean[['text', 'end']].apply(lambda x : x[1]-len(x[0]), axis = 1)
df_clean.head()
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 12     5        1         3       1        1        1  722   53    64     28
# 14     5        1         3       1        1        3  822   53   203     28
# 17     5        1         3       2        1        1   55   55    85     89
# 18     5        1         3       2        1        2  822   71   203     65
# 20     5        1         3       2        2        1  593  136    93     25
#
#    conf        text  end  start
# 12   90        cell    4      0
# 14   96  8099948528   15      5
# 17   30          te   18     16
# 18   96  8466045457   29     19
# 20   89       email   35     30

# %%
## Inner Join with Start position

dataframe_info = pd.merge(df_clean, datafram_tokens[['start', 'token', 'label']], how = 'inner', on ='start')
dataframe_info.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 0     5        1         3       1        1        1  722   53    64     28
# 1     5        1         3       1        1        3  822   53   203     28
# 2     5        1         3       2        1        1   55   55    85     89
# 3     5        1         3       2        1        2  822   71   203     65
# 4     5        1         3       2        2        1  593  136    93     25
#
#   conf        text  end  start       token    label
# 0   90        cell    4      0        cell        O
# 1   96  8099948528   15      5  8099948528  B-PHONE
# 2   30          te   18     16          te        O
# 3   96  8466045457   29     19  8466045457  B-PHONE
# 4   89       email   35     30       email        O

# %%
dataframe_info.tail()
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 46     5        1         6       3        4        1   46  571   106     21
# 47     5        1         6       3        4        2  161  576    56     22
# 48     5        1         6       3        4        3  226  571   111     21
# 49     5        1         6       3        4        4  347  571    74     21
# 50     5        1         6       3        4        5  432  571    96     27
#
#    conf      text  end  start     token label
# 46   96   promote  455    448   promote     O
# 47   96      your  460    456      your     O
# 48   96  business  469    461  business     O
# 49   92    online  476    470    online     O
# 50   92      pybo  481    477      pybo     O

# %% [markdown]
# ## Bounding Box

# %%
# Create a Specific Data Frame for bouning box

bb_df = dataframe_info.query("label != 'O' ")
img = image.copy()

for x,y,w,h,label in bb_df[['left', 'top', 'width', 'height', 'label']].values:
    x = int(x)
    y = int(y)
    w = int(w)
    h = int(h)
    
    cv2.rectangle(img, pt1 =(x,y), pt2=(x+w, y+h), color= (0,255,0), thickness = 2)
    cv2.putText(img, str(label), (x,y), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,255),2)
    

cv2.imshow('Predictions', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Combine the Bio Information

# %%
bb_df.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 1     5        1         3       1        1        3  822   53   203     28
# 3     5        1         3       2        1        2  822   71   203     65
# 5     5        1         3       2        2        3  709  136   316     31
# 6     5        1         3       3        1        1   46  170    33     14
# 7     5        1         3       3        1        2   85  151    91     42
#
#   conf                   text  end  start                  token    label
# 1   96             8099948528   15      5             8099948528  B-PHONE
# 3   96             8466045457   29     19             8466045457  B-PHONE
# 5   88  lictsrikant@gmail.com   57     36  lictsrikant@gmail.com  B-EMAIL
# 6   96                   life   62     58                   life    B-ORG
# 7   94              insurance   72     63              insurance    I-ORG

# %%
# We need to remove the first 2 letter from labels

bb_df['label'] = bb_df['label'].apply(lambda x : x[2:])
bb_df.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 1     5        1         3       1        1        3  822   53   203     28
# 3     5        1         3       2        1        2  822   71   203     65
# 5     5        1         3       2        2        3  709  136   316     31
# 6     5        1         3       3        1        1   46  170    33     14
# 7     5        1         3       3        1        2   85  151    91     42
#
#   conf                   text  end  start                  token  label
# 1   96             8099948528   15      5             8099948528  PHONE
# 3   96             8466045457   29     19             8466045457  PHONE
# 5   88  lictsrikant@gmail.com   57     36  lictsrikant@gmail.com  EMAIL
# 6   96                   life   62     58                   life    ORG
# 7   94              insurance   72     63              insurance    ORG

# %% [markdown]
# ## Group the Label

# %%
class groupgen():
    
    def __init__(self):
        self.id = 0
        self.text = ''
        
    def getgroup(self, text):
        
        if self.text ==text:
            return self.id
        else:
            self.id += 1
            self.text = text
            return self.id
        

grp_gen = groupgen()

# %%
bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)

# %%
bb_df.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 1     5        1         3       1        1        3  822   53   203     28
# 3     5        1         3       2        1        2  822   71   203     65
# 5     5        1         3       2        2        3  709  136   316     31
# 6     5        1         3       3        1        1   46  170    33     14
# 7     5        1         3       3        1        2   85  151    91     42
#
#   conf                   text  end  start                  token  label  group
# 1   96             8099948528   15      5             8099948528  PHONE      1
# 3   96             8466045457   29     19             8466045457  PHONE      1
# 5   88  lictsrikant@gmail.com   57     36  lictsrikant@gmail.com  EMAIL      2
# 6   96                   life   62     58                   life    ORG      3
# 7   94              insurance   72     63              insurance    ORG      3

# %% [markdown]
# ### Right and Bottom of Bounding Box

# %%
bb_df[['left', 'top', 'width', 'height']] = bb_df[['left', 'top', 'width', 'height']].astype(int)

bb_df['right'] = bb_df['left']+ bb_df['width']
bb_df['bottom'] = bb_df['top']+ bb_df['height']

bb_df.head()
# Out:
#   level page_num block_num par_num line_num word_num  left  top  width  \
# 1     5        1         3       1        1        3   822   53    203
# 3     5        1         3       2        1        2   822   71    203
# 5     5        1         3       2        2        3   709  136    316
# 6     5        1         3       3        1        1    46  170     33
# 7     5        1         3       3        1        2    85  151     91
#
#    height conf                   text  end  start                  token  \
# 1      28   96             8099948528   15      5             8099948528
# 3      65   96             8466045457   29     19             8466045457
# 5      31   88  lictsrikant@gmail.com   57     36  lictsrikant@gmail.com
# 6      14   96                   life   62     58                   life
# 7      42   94              insurance   72     63              insurance
#
#    label  group  right  bottom
# 1  PHONE      1   1025      81
# 3  PHONE      1   1025     136
# 5  EMAIL      2   1025     167
# 6    ORG      3     79     184
# 7    ORG      3    176     193

# %% [markdown]
# ### Tagging : GroupBy Group

# %%
col_group = ['left','top', 'right', 'bottom', 'token', 'label', 'group']
group_tag_img = bb_df[col_group].groupby(by = 'group')
group_tag_img

# %%
img_tagging = group_tag_img.agg({
    
    'left': min,
    'right': max,
    'top' : min,
    'bottom': max,
    'label' : np.unique ,
    'token' : lambda x: " ".join(x)
    
})

# %%
img_tagging.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 1 to 8
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   left    8 non-null      int32
#  1   right   8 non-null      int32
#  2   top     8 non-null      int32
#  3   bottom  8 non-null      int32
#  4   label   8 non-null      object
#  5   token   8 non-null      object
# dtypes: int32(4), object(2)
# memory usage: 320.0+ bytes

# %%
img_tagging['label'] = img_tagging['label'].apply(lambda x: str(x))

# %%
img_bb = image.copy()

for l, r, t, b, label, token in img_tagging.values:
    
    cv2.rectangle(img_bb, (l,t), (r,b), (0,255,0), 2)
    cv2.putText(img_bb, label,(l,t), cv2.FONT_HERSHEY_PLAIN, 1, (255,0,0), 2)
    
cv2.imshow('Bounding Box for Business Card', img_bb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Parser

# %%
def parser(text, label):
    
    if label == 'PHONE':
        text = text.lower()
        text = re.sub(r'\D', '', text)
        
    elif label == 'EMAIL':
        text = text.lower()
        allow_special_char = '\@-_.'
        text = re.sub(r'[^A-Za-z0-9{}]'.format(allow_special_char), '', text)
        
        
    elif label == 'WEB':
        text = text.lower()
        allow_special_char = ':\/.%#-'
        text = re.sub(r'[^A-Za-z0-9{}]'.format(allow_special_char), '', text)
        
        
    elif label in ('NAME', 'DES'):
        text = text.lower()
        text = re.sub(r'[^a-z]', '', text)
        text = text.title()
                   
        
    elif label == 'ORG':
        text = text.lower()
        text = re.sub(r'[^a-z0-9]', '', text)
        text = text.title()
        
    return text

# %%
# Verification

parser('deedhd2232323g323b@#$%^&*(2', 'EMAIL')
# Out:
# 'deedhd2232323g323b@^2'

# %% [markdown]
# ## Entities

# %%
dataframe_info.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 0     5        1         3       1        1        1  722   53    64     28
# 1     5        1         3       1        1        3  822   53   203     28
# 2     5        1         3       2        1        1   55   55    85     89
# 3     5        1         3       2        1        2  822   71   203     65
# 4     5        1         3       2        2        1  593  136    93     25
#
#   conf        text  end  start       token    label
# 0   90        cell    4      0        cell        O
# 1   96  8099948528   15      5  8099948528  B-PHONE
# 2   30          te   18     16          te        O
# 3   96  8466045457   29     19  8466045457  B-PHONE
# 4   89       email   35     30       email        O

# %%
info_array = dataframe_info[['token','label']].values
entities = dict(NAME=[],ORG=[],DES=[],PHONE=[],EMAIL=[],WEB=[])
previous = 'O'

for token, label in info_array:
    bio_tag = label[0]
    label_tag = label[2:]

    # step -1 parse the token
    text = parser(token,label_tag)

    if bio_tag in ('B','I'):
        if previous != label_tag:
            entities[label_tag].append(text)

        else:
            if bio_tag == "B":
                entities[label_tag].append(text)
            else:
                if label_tag in ("NAME",'ORG','DES'):
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text
                else:
                    entities[label_tag][-1] = entities[label_tag][-1] + text


    previous = label_tag

# %%
entities
# Out:
# {'NAME': ['Thathineni Srikanth'],
#  'ORG': ['Life Insurance Corporation Of India',
#   'Life Insurance Corporation Of India'],
#  'DES': ['Insurance Advisor'],
#  'PHONE': ['8099948528', '8466045457'],
#  'EMAIL': ['lictsrikant@gmail.com', 'seosrikantht@gmail.com'],
#  'WEB': ['lictsrikant8099948528.blogspot.in',
#   'interviewsinhyderabad.blogspot.in']}
